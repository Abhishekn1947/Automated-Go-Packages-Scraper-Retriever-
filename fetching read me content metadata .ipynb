# %%
import requests
from bs4 import BeautifulSoup

def scrape_go_package_metadata(package_url):
    response = requests.get(package_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        overview_content = soup.find('div', class_='Overview-readmeContent js-readmeContent')
        if overview_content:
            print(overview_content.get_text().strip())
        else:
            print("Could not find the specified div class.")
    else:
        print(f"Failed to fetch URL. Status code: {response.status_code}")

if __name__ == "__main__":
    package_url = input("Enter the package URL: ")
    scrape_go_package_metadata(package_url)
# Out:
# Enter the package URL: https://pkg.go.dev/github.com/mspgeek-community/matterbridge
# matterbridge
#
# A simple chat bridge
# Letting people be where they want to be.
# Bridges between a growing number of protocols. Click below to demo or join the development chat.
#
# Discord |
# Gitter |
# IRC |
# Keybase |
# Matrix |
# Mattermost |
# MSTeams |
# Rocket.Chat |
# Slack |
# Telegram |
# Twitch |
# WhatsApp |
# XMPP |
# Zulip |
# And more...
#
#
#
#
#
#
#
#
# Note: Mattermost isn't required to run matterbridge.
#
#
#
#
#
# Table of Contents
#
# matterbridge
# Table of Contents
#
# Features
#
# Natively supported
# 3rd party via matterbridge api
# API
#
#
# Chat with us
# Screenshots
# Installing / upgrading
#
# Binaries
# Packages
#
#
# Building
# Building with whatsapp (beta) multidevice support
# Configuration
#
# Basic configuration
# Settings
# Advanced configuration
#
# Examples
#
# Bridge mattermost (off-topic) - irc (#testing)
# Bridge slack (#general) - discord (general)
#
#
# ...
