# %%
import requests
from bs4 import BeautifulSoup
import json

def get_metadata(base_url, repo_url):
    response = requests.get(f"{base_url}/{repo_url}")
    soup = BeautifulSoup(response.content, "html.parser")

    package_name_element = soup.select_one('div.UnitMeta-repo a')
    if package_name_element:
        package_name = package_name_element.text.strip()
    else:
        package_name = "Package name not available."

    version_box = soup.find('div', class_="Versions-list")
    version_links = version_box.find_all("a", class_="js-versionLink")

    metadata_list = []

    for version_link in version_links:
        version_url = f"{base_url}{version_link['href']}"
        version_response = requests.get(version_url)
        version_soup = BeautifulSoup(version_response.content, "html.parser")

        version_number = version_link.text.strip()
        license_element = version_soup.find('span', class_='License')

        if license_element:
            license_info = license_element.text.strip()
        else:
            license_info = "License information not available."

        version_metadata = {
            "version": version_number,
            "license": license_info
        }

        # Fetch additional details for each version
        details_box = version_soup.find('ul', class_="UnitMeta-details").find_all("li")
        go_mod_raw, license_raw, tag_raw, is_stable_raw, more_link_raw = details_box

        go_mod_link = go_mod_raw.find("a")["href"]
        license_dist = True if "check" in license_raw.find("img")["src"] else False
        is_tagged = True if "check" in tag_raw.find("img")["src"] else False
        is_stable = False if "cancel" in is_stable_raw.find("img")["src"] else True

        # Append additional details to the metadata for this version
        version_metadata["details"] = go_mod_link
        version_metadata["redistributable_license"] = license_dist
        version_metadata["tagged_version"] = is_tagged
        version_metadata["stable_version"] = is_stable
        # Add more fields as needed for other details

        metadata_list.append(version_metadata)

    return package_name, metadata_list

base_url = "https://pkg.go.dev"
repo_url = "kraftkit.sh/unikraft/arch?tab=versions"

package_name, metadata_list = get_metadata(base_url, repo_url)

package_url_template = "https://pkg.go.dev/kraftkit.sh@{version}/unikraft/arch"

for metadata in metadata_list:
    version = metadata["version"]
    package_url = package_url_template.format(version=version)
    metadata["package_url"] = package_url

    response = requests.get(package_url)
    if response.status_code == 200:
        html = BeautifulSoup(response.content, "html.parser")
        package_license_element = html.select_one('*[data-test-id="UnitHeader-license"]')

        if package_license_element:
            package_license = package_license_element.text.strip()
            metadata["package_license"] = package_license
        else:
            metadata["package_license"] = "License: N/A"
    else:
        metadata["package_license"] = "Failed to fetch package details."

output = {
    "package_name": package_name,
    "metadata": metadata_list
}

with open("metadata.json", "w") as json_file:
    json.dump(output, json_file, indent=4)

for metadata in metadata_list:
    print(f"Version: {metadata['version']}")
    print(f"Package URL: {metadata['package_url']}")
    print(f"License: {metadata['package_license']}")
    print(f"Details: {metadata['details']}")
    print(f"Redistributable License: {metadata['redistributable_license']}")
    print(f"Tagged Version: {metadata['tagged_version']}")
    print(f"Stable Version: {metadata['stable_version']}")
    print("------------------------")
# Out:
# Version: v0.6.4
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6.4/unikraft/arch
# License: BSD-3-Clause
# Details: https://github.com/unikraft/kraftkit/tree/v0.6.4/go.mod
# Redistributable License: True
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.6.4-98-g0f3ebc3
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6.4-98-g0f3ebc3/unikraft/arch
# License: BSD-3-Clause
# Details: https://github.com/unikraft/kraftkit/tree/v0.6.4-98-g0f3ebc3/go.mod
# Redistributable License: True
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.6.4-95-g1f4cb63
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6.4-95-g1f4cb63/unikraft/arch
# License: BSD-3-Clause
# Details: https://github.com/unikraft/kraftkit/tree/v0.6.4-95-g1f4cb63/go.mod
# Redistributable License: True
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.6.4-92-g8f4c405
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6.4-92-g8f4c405/unikraft/arch
# License: BSD-3-Clause
# Details: https://github.com/unikraft/kraftkit/tree/v0.6.4-92-g8f4c405/go.mod
# Redistributable License: True
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.6.4-90-g8ea7051
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6.4-90-g8ea7051/unikraft/arch
# License: BSD-3-Clause
# Details: https://github.com/unikraft/kraftkit/tree/v0.6.4-90-g8ea7051/go.mod
# Redistributable License: True
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.6.4-86-g20225fb
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.6
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-359-g9561b4f
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-359-g9561b4f/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-359-g9561b4f/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-358-g7d84a3f
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-358-g7d84a3f/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-358-g7d84a3f/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-356-g8497a51
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-356-g8497a51/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-356-g8497a51/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-354-g13e54b2
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-354-g13e54b2/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-354-g13e54b2/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-326-g50abe87
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-326-g50abe87/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-326-g50abe87/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-325-g5d2e73b
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-325-g5d2e73b/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-325-g5d2e73b/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-324-g10e7b50
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-324-g10e7b50/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-324-g10e7b50/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-322-g47f6b3c
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-322-g47f6b3c/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-322-g47f6b3c/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-321-gf82b914
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-321-gf82b914/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-321-gf82b914/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-316-g50264f2
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-316-g50264f2/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-316-g50264f2/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-313-gbcf5615
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-313-gbcf5615/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-313-gbcf5615/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-311-gfd64e7c
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-311-gfd64e7c/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-311-gfd64e7c/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------
# Version: v0.0.0-310-gb163414
# Package URL: https://pkg.go.dev/kraftkit.sh@v0.0.0-310-gb163414/unikraft/arch
# License: License: N/A
# Details: https://github.com/unikraft/kraftkit/tree/v0.0.0-310-gb163414/go.mod
# Redistributable License: False
# Tagged Version: True
# Stable Version: False
# ------------------------

# %%
data_list = []
package_url = "https://pkg.go.dev/kraftkit.sh"
response = requests.get(package_url)
text = ""
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    overview_content = soup.find('div', class_='Overview-readmeContent js-readmeContent')
    if overview_content:
            text = overview_content.get_text().strip()
            print(text)
            for metadata in metadata_list:
                metadata['readme'] = text
                data_list.append(metadata)
    else:
            print("Could not find the specified div class.")
else:
        print(f"Failed to fetch URL. Status code: {response.status_code}")
# Out:
# KraftKit 🚀🐒🧰
#
#
#
#
#
# KraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.
#
# With KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.
#
# Getting started guide 📖
# Key differences between containers and unikernels 🤔
# Join #kraftkit on Unikraft's Community Discord 👾
#
# There are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.
# Features
#
# 🔥 Native Firecracker MicroVM support;
# 📚 Pre-built unikernel app catalog;
# 🤹‍♀️ Daemonless unikernel VM instance manager;
# 📦 OCI packaging and distribution support;
# 🚜 ELF binary / POSIX-compatibility support;
# 🧰 Go SDK for building unikernels programmatically; and
# 🚀 much more!
#
# Installation
# You can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:
# curl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh
#
# Alternatively, you can download the binaries from the releases pages.
# Container build environment
# KraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.
# It includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.
# Simply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:
# docker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest
#
# The above command will drop you into a container shell.
# Simply type exit or Ctrl+D to quit.
# Quickstart
# Building a unikernel with KraftKit is designed to be simple.
# Add a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:
# specification: v0.5
#
# unikraft: stable
#
# libraries:
#   newlib: stable
#
# targets:
#   - name: default
#     architecture: x86_64
#     platform: kvm
#
# You can also add an additional Makefile.uk which specifies any source files:
# $(eval $(call addlib,apphelloworld))
#
# APPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c
#
# Then it is a case of running:
# cd path/to/workdir
#
# kraft pkg update
# kraft build
#
# You can run your unikernel using:
# kraft run
#
# Support, Community & Meetings
# If you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.
# A KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.
# Invites and additional details are available on the Unikraft OSS Public calendar.
# License
# KraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause.

# %%
data_list
# Out:
# [{'version': 'v0.6.4',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-98-g0f3ebc3',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-98-g0f3ebc3/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-98-g0f3ebc3/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-95-g1f4cb63',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-95-g1f4cb63/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-95-g1f4cb63/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-92-g8f4c405',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-92-g8f4c405/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-92-g8f4c405/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-90-g8ea7051',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-90-g8ea7051/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-90-g8ea7051/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-86-g20225fb',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-86-g20225fb/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-86-g20225fb/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-84-gb14725b',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-84-gb14725b/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-84-gb14725b/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-82-g19055f2',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-82-g19055f2/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-82-g19055f2/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-80-g2fba223',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-80-g2fba223/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-80-g2fba223/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-8-g2915a78',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-8-g2915a78/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-8-g2915a78/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-78-g38a5be2',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-78-g38a5be2/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-78-g38a5be2/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-76-ga101670',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-76-ga101670/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-76-ga101670/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-73-gcf6f075',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-73-gcf6f075/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-73-gcf6f075/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.6.4-63-g8b08d25',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.6.4-63-g8b08d25/go.mod',
#   'redistributable_license': True,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.6.4-63-g8b08d25/unikraft/arch',
#   'package_license': 'BSD-3-Clause',
# ...
#  {'version': 'v0.0.0-316-g50264f2',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.0.0-316-g50264f2/go.mod',
#   'redistributable_license': False,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.0.0-316-g50264f2/unikraft/arch',
#   'package_license': 'License: N/A',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.0.0-313-gbcf5615',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.0.0-313-gbcf5615/go.mod',
#   'redistributable_license': False,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.0.0-313-gbcf5615/unikraft/arch',
#   'package_license': 'License: N/A',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.0.0-311-gfd64e7c',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.0.0-311-gfd64e7c/go.mod',
#   'redistributable_license': False,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.0.0-311-gfd64e7c/unikraft/arch',
#   'package_license': 'License: N/A',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."},
#  {'version': 'v0.0.0-310-gb163414',
#   'license': 'License information not available.',
#   'details': 'https://github.com/unikraft/kraftkit/tree/v0.0.0-310-gb163414/go.mod',
#   'redistributable_license': False,
#   'tagged_version': True,
#   'stable_version': False,
#   'package_url': 'https://pkg.go.dev/kraftkit.sh@v0.0.0-310-gb163414/unikraft/arch',
#   'package_license': 'License: N/A',
#   'readme': "KraftKit 🚀🐒🧰\n\n\n\n\n\nKraftKit provides a suite of tools and Go-based framework for building custom, minimal, immutable lightweight unikernel virtual machines based on Unikraft: a fast, secure and open-source library operating system.\n\nWith KraftKit, you can easily leverage Unikraft and manage specialized, high-performance applications at every stage of their lifecycle: from construction to production.\n\nGetting started guide 📖\nKey differences between containers and unikernels 🤔\nJoin #kraftkit on Unikraft's Community Discord 👾\n\nThere are many benefits in running your application as a unikernel: for more information about the performance of unikernels 🚀, the added security 🔒 and a positive impact on the environment 🌱 please check out Unikraft's documentation and the introductory chapters on these impacts.\nFeatures\n\n🔥 Native Firecracker MicroVM support;\n📚 Pre-built unikernel app catalog;\n🤹\u200d♀️ Daemonless unikernel VM instance manager;\n📦 OCI packaging and distribution support;\n🚜 ELF binary / POSIX-compatibility support;\n🧰 Go SDK for building unikernels programmatically; and\n🚀 much more!\n\nInstallation\nYou can quickly and easily install KraftKit using the interactive installer.  Simply run the following command to get started:\ncurl --proto '=https' --tlsv1.2 -sSf https://get.kraftkit.sh | sh\n\nAlternatively, you can download the binaries from the releases pages.\nContainer build environment\nKraftKit ships a container build environment which you can use instead of installing any dependencies directly on your host.\nIt includes the kraft binary as well as all the additional tools and libraries for building Unikraft unikernels.\nSimply attach a working directory on your host as a mount path volume mapped to /workspace, e.g.:\ndocker run -it --rm -v $(pwd):/workspace --entrypoint bash kraftkit.sh/base:latest\n\nThe above command will drop you into a container shell.\nSimply type exit or Ctrl+D to quit.\nQuickstart\nBuilding a unikernel with KraftKit is designed to be simple.\nAdd a Kraftfile to your project directory, which specifies the libraries needed for your unikernel:\nspecification: v0.5\n\nunikraft: stable\n\nlibraries:\n  newlib: stable\n\ntargets:\n  - name: default\n    architecture: x86_64\n    platform: kvm\n\nYou can also add an additional Makefile.uk which specifies any source files:\n$(eval $(call addlib,apphelloworld))\n\nAPPHELLOWORLD_SRCS-y += $(APPHELLOWORLD_BASE)/main.c\n\nThen it is a case of running:\ncd path/to/workdir\n\nkraft pkg update\nkraft build\n\nYou can run your unikernel using:\nkraft run\n\nSupport, Community & Meetings\nIf you have any further questions or need more information about KraftKit or Unikraft, please refer to the official Unikraft documentation or ask for help on the Unikraft community forum.\nA KraftKit Working Group (WG) meets every Wednesday at 12:30 PM (CET) on Discord.\nInvites and additional details are available on the Unikraft OSS Public calendar.\nLicense\nKraftKit is part of the Unikraft OSS Project and licensed under BSD-3-Clause."}]
